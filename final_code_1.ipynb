# %% [markdown]
# <a href="https://colab.research.google.com/github/Anindya-R0y/dip-git/blob/main/final_code_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Cloning yolov5 repo from https://github.com/ultralytics/yolov5

# %%
 # !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16074, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 16074 (delta 5), reused 9 (delta 1), pack-reused 16056
# Receiving objects: 100% (16074/16074), 14.69 MiB | 28.44 MiB/s, done.
# Resolving deltas: 100% (11033/11033), done.

# %% [markdown]
# Checking the location of yolov5 clone

# %%
cd yolov5
# Out:
# /content/yolov5

# %% [markdown]
# Installing the requirements to run yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 4.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.7/645.7 kB 34.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 10.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 9.4.0
#     Uninstalling Pillow-9.4.0:
#       Successfully uninstalled Pillow-9.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# imageio 2.31.6 requires pillow<10.1.0,>=8.3.2, but you have pillow 10.1.0 which is incompatible.
# ...

# %% [markdown]
# Mounting in google drive for getting the dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Unzipping the dataset folder present in google

# %%
# !unzip "/content/drive/My Drive/dataset.zip"
# Out:
# Archive:  /content/drive/My Drive/dataset.zip
#    creating: dataset/images/
#    creating: dataset/images/Train/
#   inflating: dataset/images/Train/1000_F_512432281_wHqlWBJfYtIhEB0diygZu5qgx4rLj2nE.jpg
#   inflating: dataset/images/Train/12843404.jpg
#   inflating: dataset/images/Train/156297981-detail-of-a-round-traffic-sign-with-red-border-and-black-limit-number-80-km-h-mph.jpg
#   inflating: dataset/images/Train/2018_09_deerwood.jpg
#   inflating: dataset/images/Train/2173823-a-traffic-sign-of-speed-limit-70.jpg
#   inflating: dataset/images/Train/290118976.jpg
#   inflating: dataset/images/Train/45403233-night-speed-limit-70-signboard.jpg
#   inflating: dataset/images/Train/45576764-temporary-road-sign-in-canada-speed-limit-80-kmh-this-sign-is-used-in-quebec.jpg
#   inflating: dataset/images/Train/6452acca02b18.image.jpg
#   inflating: dataset/images/Train/96309624.jpg
#   inflating: dataset/images/Train/australia-signs-traffic-output-80km-wallpaper-preview.jpg
# ...

# %% [markdown]
# Checking for GPU in runtime(need to enable the GPU while selecting the runtime)

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# **Function to Monitor TensorBoard logs**.

# %%
def monitor_tensorboard():
    # %load_ext tensorboard
    # %tensorboard --logdir runs/train

# %% [markdown]
# Training the yolov5s model

# %%
# !python train.py --data /content/yolov5/data/custom_dataset.yaml --weights yolov5s.pt \
    --img 640 --epochs 100 --batch-size 16 --name {RES_DIR}
# Out:
# 2023-11-22 05:01:26.506710: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 05:01:26.506770: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 05:01:26.506810: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# ## Check Out the Validation Predictions and Inference
#
# In this section, we will check out the predictions of the validation images saved during training. Along with that, we will also check out inference of images.

# %%
# !python detect.py --weight /content/yolov5/runs/train/{RES_DIR}2/weights/best.pt --source /content/yolov5/dataset/images/val
# Out:
# detect: weights=['/content/yolov5/runs/train/{RES_DIR}2/weights/best.pt'], source=/content/yolov5/dataset/images/val, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-245-g3d8f004 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# image 1/176 /content/yolov5/dataset/images/val/1000_F_227893429_GSDFDVEXug2TuVMsMDVAFdTJbiK6Y3me.jpg: 448x640 1 speed limit 80km/h, 71.0ms
# image 2/176 /content/yolov5/dataset/images/val/319px-80_kmh_speed_limit_sign.jpg: 640x448 1 speed limit 80km/h, 67.7ms
# ...
